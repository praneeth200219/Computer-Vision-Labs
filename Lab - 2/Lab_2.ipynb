# %% [markdown]
# # CV - Lab 2

# %% [markdown]
# ## Praneeth Nemani - 191000035

# %%
# !git clone https://github.com/praneeth200219/Computer-Vision-Labs.git
# Out:
# Cloning into 'Computer-Vision-Labs'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 43 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %% [markdown]
# # 1. Opening and Closing

# %%
import cv2
img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Patterson_0001.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# to use it in a loop
k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('messigray.png',img)
    cv2.destroyAllWindows()

cv2.imshow('image',img)

# %% [markdown]
# # 2. Morphological Transformations

# %% [markdown]
# ### 2.1 Dilation

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 2/IMG_0155.JPG')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((5,5), np.uint8)
img_dilation = cv2.dilate(img, kernel, iterations=1)
plt.imshow(img)

# %%
plt.imshow(img_dilation)

# %% [markdown]
# ## 2.2 Erosion

# %%
img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Abba_Eban_0001.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
kernel = np.ones((5,5), np.uint8)
img_erosion = cv2.erode(img, kernel, iterations=1)
plt.imshow(img)

# %%
plt.imshow(img_erosion)

# %% [markdown]
# ## 2.3 Hit or Miss

# %%
img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Abba_Eban_0001.jpg')
image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
kernel = np.ones((5,5), np.uint8)
output_image = cv2.morphologyEx(img, cv2.MORPH_HITMISS, kernel)
output_image = cv2.cvtColor(output_image, cv2.COLOR_GRAY2RGB)
plt.imshow(output_image)

# %%
plt.imshow(image)

# %% [markdown]
# ## 2.4. Skeletonization

# %%
import cv2
import numpy as np
 
img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Eckhart_0001.jpg',0)
im1 = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Eckhart_0001.jpg',0)
size = np.size(img)
skel = np.zeros(img.shape,np.uint8)
 
ret,img = cv2.threshold(img,127,255,0)
element = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
done = False
 
while( not done):
    eroded = cv2.erode(img,element)
    temp = cv2.dilate(eroded,element)
    temp = cv2.subtract(img,temp)
    skel = cv2.bitwise_or(skel,temp)
    img = eroded.copy()
 
    zeros = size - cv2.countNonZero(img)
    if zeros==size:
        done = True
 
img = cv2.cvtColor(im1, cv2.COLOR_BGR2RGB)
plt.subplot(2,2,1),plt.imshow(img)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(skel,cmap = 'gray')
plt.title('Skeletion'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Skeletion'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# ## 2.5 Thinning

# %%
image = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Patterson_0001.jpg')
thinned = cv2.ximgproc.thinning(cv2.cvtColor(image, cv2.COLOR_RGB2GRAY))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.subplot(2,2,1),plt.imshow(image,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(thinned,cmap = 'gray')
plt.title('Thinning'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Thinning'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# # 3. Edge Detection

# %% [markdown]
# ## 3.1. Sobel Edge Detection

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img0 = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Eckhart_0001.jpg')

# converting to gray scale
gray = cv2.cvtColor(img0, cv2.COLOR_BGR2GRAY)

# remove noise
img = cv2.GaussianBlur(gray,(3,3),0)

# convolute with proper kernels
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)  # x
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)  # y

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ## 3.2 Prewitt

# %%
import cv2
import numpy as np

img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Eckhart_0001.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gaussian = cv2.GaussianBlur(gray,(3,3),0)
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(img_prewittx,cmap = 'gray')
plt.title('Prewitt X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(img_prewitty,cmap = 'gray')
plt.title('Prewitt Y'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Prewitt Y'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# ## 3.3 Canny

# %%
img_canny = cv2.Canny(img,100,200)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(img_canny,cmap = 'gray')
plt.title('Canny Image'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Canny Image'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# ## 3.4 Robert Detectors

# %%
import sys
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
from skimage import io

plt.rcParams['figure.figsize'] = [15, 10]

roberts_cross_v = np.array( [[ 0, 0, 0 ],
                             [ 0, 1, 0 ],
                             [ 0, 0,-1 ]] )

roberts_cross_h = np.array( [[ 0, 0, 0 ],
                             [ 0, 0, 1 ],
                             [ 0,-1, 0 ]] )

img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Guiel_0001.jpg')

img = img.astype('float64')
gray_img = np.dot(img[...,:3], [0.2989, 0.5870, 0.1140])
gray_img /= 255
vertical = ndimage.convolve( gray_img, roberts_cross_v )
horizontal = ndimage.convolve( gray_img, roberts_cross_h )

edged_img = np.sqrt( np.square(horizontal) + np.square(vertical))
plt.imshow(edged_img, cmap=plt.get_cmap('gray'))

plt.subplot(2,2,1),plt.imshow(gray_img)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(edged_img,cmap = 'gray')
plt.title('Robert'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Robert'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %% [markdown]
# ## 3.5 LoG Detectors

# %%
import cv2
import numpy as np

img = cv2.imread('/content/Computer-Vision-Labs/CV- Dataset/Dataset - 1/Aaron_Eckhart_0001.jpg',0)
blur = cv2.GaussianBlur(img,(3,3),0)
laplacian = cv2.Laplacian(blur,cv2.CV_64F)
laplacian1 = laplacian/laplacian.max()

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian1,cmap = 'gray')
plt.title('LoG'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'LoG'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))
